# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('Loan_default.csv')

# Drop the 'LoanID' column
df = df.drop(columns=['LoanID'])

# Display basic statistics of the dataset
print(df.describe())
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
# Create histograms for Age and Income
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df['Age'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')

plt.subplot(1, 2, 2)
plt.hist(df['Income'], bins=20, color='salmon', edgecolor='black')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.title('Income Distribution')

plt.tight_layout()
plt.show()

# %%
# Bar chart for loan purpose
plt.figure(figsize=(10, 6))
sns.countplot(x='LoanPurpose', data=df, palette='Set2')
plt.xlabel('Loan Purpose')
plt.ylabel('Count')
plt.title('Loan Purpose Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
# Aggregate data for box plots
aggregated_data = df.groupby('Education')['LoanAmount'].median().reset_index()

# Create box plots for aggregated data
plt.figure(figsize=(10, 6))
sns.boxplot(x='Education', y='LoanAmount', data=aggregated_data)
plt.title('Median Loan Amount by Education Level')
plt.xticks(rotation=45)
plt.show()

# %%
import plotly.express as px

# Sample data for interactive scatter plot
sampled_data = df.sample(n=1000)  # Adjust the sample size as needed

# Create an interactive scatter plot
fig = px.scatter(sampled_data, x='Age', y='LoanAmount', color='CreditScore')
fig.update_traces(marker=dict(size=5))
fig.update_layout(title='Interactive Scatter Plot', xaxis_title='Age', yaxis_title='Loan Amount')
fig.show()
